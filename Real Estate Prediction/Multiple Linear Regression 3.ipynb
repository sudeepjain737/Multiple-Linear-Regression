# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing the Dataset

# %%
dataset = pd.read_csv("Real estate.csv")
dataset
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
dataset = dataset.drop(['No','X1 transaction date'],axis = 1)
dataset
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# 0            32.0                                84.87882
# 1            19.5                               306.59470
# 2            13.3                               561.98450
# 3            13.3                               561.98450
# 4             5.0                               390.56840
# ..            ...                                     ...
# 409          13.7                              4082.01500
# 410           5.6                                90.45606
# 411          18.8                               390.96960
# 412           8.1                               104.81010
# 413           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# ...

# %% [markdown]
# ## Taking care of Missing data

# %%
dataset.isna().sum()
# Out:
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
sns.heatmap(dataset.isna(),cbar=True,cmap='summer')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Visualising the Data

# %% [markdown]
# ### ScatterPlot

# %%
for i in dataset:
    sns.scatterplot(x=i,y='Y house price of unit area',data=dataset)
    plt.show()

# %% [markdown]
# ### Line Plot

# %%
for i in dataset:
    sns.lineplot(x=i,y='Y house price of unit area',data=dataset)
    plt.show()

# %% [markdown]
# ### Regression Plot

# %%
for i in dataset:
    sns.regplot(x = i, y = 'Y house price of unit area' , data = dataset)
    plt.show()

# %%
x = dataset.drop('Y house price of unit area',axis = 1)
y = dataset['Y house price of unit area']

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# ## Training the Multiple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set Results

# %%
y_pred = reg.predict(x_test)

# %% [markdown]
# ## Model Score on Training data

# %%
reg.score(x_train,y_train)
# Out:
# 0.5372179466923419

# %% [markdown]
# ## Model Score on Test data

# %%
reg.score(x_test,y_test)
# Out:
# 0.7007314553053378
